# %% [markdown]
# # Phase 2B — Token-level on-policy distillation (TRL GKD)
#
# **The stretch.** An open-weights teacher grades every student token; student trains to match the teacher's per-token distribution. Run on the **A100**, watch VRAM (7B student + 14B+ teacher in memory while generating).
#
# Demonstration: run twice changing only `lmbda` — `0.0` (≈ off-policy) vs `1.0` (fully on-policy) — and compare dev EX.
#
# Placeholder scaffold — see `docs/guide.v2.0.md` §6.3.

# %%
# !pip install -q trl peft accelerate bitsandbytes datasets transformers
import torch
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "NONE")

# %%
# from trl.experimental.gkd import GKDConfig, GKDTrainer
# from transformers import AutoModelForCausalLM, AutoTokenizer
#
# student = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2.5-Coder-7B-Instruct")
# teacher = AutoModelForCausalLM.from_pretrained("Qwen/Qwen2.5-Coder-14B-Instruct")
# tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen2.5-Coder-7B-Instruct")
#
# config = GKDConfig(output_dir="gkd-out", per_device_train_batch_size=1,
#                    gradient_accumulation_steps=8, learning_rate=5e-5,
#                    lmbda=0.5,   # 0=off-policy, 1=fully on-policy
#                    beta=0.5,    # 0=forward KL, 1=reverse KL, between=JSD
#                    max_new_tokens=512)
# trainer = GKDTrainer(model=student, teacher_model=teacher, args=config,
#                      train_dataset=ds, processing_class=tokenizer)
# trainer.train()
